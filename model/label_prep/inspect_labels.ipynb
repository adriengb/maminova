# %%
import pandas as pd

# %%
pd.options.display.max_rows = 999

# %%
labels = pd.read_csv('output.csv')

# %%
len(labels[labels.image_name=='cdn2.chrono24.com'])
# Out:
# 187

# %%
labels.head()
# Out:
#        brand condition        image_name  \
# 0  breitling  1 (mint)  7370926b_xxl.jpg
# 1  breitling  1 (mint)  7370926c_xxl.jpg
# 2  breitling  1 (mint)  7370926d_xxl.jpg
# 3  breitling  1 (mint)  7370926e_xxl.jpg
# 4  breitling  1 (mint)  7370926f_xxl.jpg
#
#                                           image_urls  \
# 0  https://cdn2.chrono24.com/images/uhren/images_...
# 1  https://cdn2.chrono24.com/images/uhren/images_...
# 2  https://cdn2.chrono24.com/images/uhren/images_...
# 3  https://cdn2.chrono24.com/images/uhren/images_...
# 4  https://cdn2.chrono24.com/images/uhren/images_...
#
#                                        location         model   price     ref  \
# 0  united states of america, new york, new york  montbrillant  $5,035  a19030
# 1  united states of america, new york, new york  montbrillant  $5,035  a19030
# 2  united states of america, new york, new york  montbrillant  $5,035  a19030
# ...

# %%
labels.brand.value_counts()
# Out:
# rolex               74197
# omega               21302
# jaeger-lecoultre    18583
# cartier             13327
# breitling            8879
# Name: brand, dtype: int64

# %%
labels.groupby(['brand', 'model']).image_name.count()
# Out:
# brand             model
# breitling         aerospace                                                 115
#                   aerospace avantage                                         67
#                   aerospace evo                                              37
#                   airwolf                                                    30
#                   antares                                                    24
#                   avenger                                                    32
#                   avenger bandit                                             38
#                   avenger blackbird                                          14
#                   avenger blackbird 44                                       25
#                   avenger hurricane                                          58
#                   avenger ii                                                 34
# ...
